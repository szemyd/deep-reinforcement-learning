# %% [markdown]
# # DDPG Agent

# %% [markdown]
# ## Import necessary modules

# %%
# --- General NN and math libraries --- #
import numpy as np
import torch

# --- For Measuring performance --- #
from collections import deque
from statistics import mean, stdev
import matplotlib.pyplot as plt

# --- For Loading the environment --- #
from .unity import environment_loader

# --- For plotting and saving --- #
from .constants import *             # Capital lettered variables are constants from the constants.py file
import time
import csv
from utilities.monitor import render_save_graph, save_scores, read_scores
print_constants()

# --- Loading and Nameing utilities --- #
from utilities.helper import load_previous, get_constant_string
# Out:
# --- General Training parameters ---
# DEVICE:  cpu
# SCORES_WINDOW:  100
# SAVE_PATH:  Trained_Agents/
# SAVE_EXP_PATH:  Experiments/
#
# --- Replay Buffer parameters ---
# BUFFER_SIZE:  100000
# UPDATE_EVERY:  4
# BATCH_SIZE:  100
#
# --- Learning parameters ---
# GAMMA:  0.99
# LR_ACTOR:  0.0001
# LR_CRITIC:  0.0001
# CRITERION:  <function mse_loss at 0x12e887670>
# WEIGHT_DECAY:  0
# TAU:  0.001
#
# --- OUNoise ---
# MU:  0.0
# THETA:  0.15
# SIGMA:  0.05

# %%
# --- For Loading the agent --- #
# We don't need to reimport the agent everytime we change one of it's values
# %load_ext autoreload
# %autoreload 2
from agent import DDPG_Agent
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Environment
# Environment is loaded with a helper function in ENV.py
# The helper function returns the envrionment object, the state size and action size, the brain's name and how many agents there are in the environment

# %%
env, state_size, action_size, brain_name, num_agents = environment_loader("Reacher_Single/Reacher.exe", no_graphics = True)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# # Train Agent

# %%
score_history = []

# %%
def DDPG_train(agent, env, max_t=100, num_episodes = 1, scores_window=SCORES_WINDOW, existing_score=[]):
    [score_history.append(i) for i in existing_score]
    print("Continuing training -> initial Score History length: ", len(score_history))
    
    scores_deque = deque(score_history[-scores_window:], maxlen=scores_window)
    last_running_mean = float('-inf')

    for episode in range(num_episodes):
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        agent.reset()                                          # reset the noise in the agent
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores = np.zeros(num_agents)                          # initialize the score (for each agent)
        score = 0

        for i in range(max_t):
            actions = agent.act(states[0])                     # select an action (for each agent)
            env_info = env.step(actions)[brain_name]           # send all actions to the environment
            
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished

            agent.step(states[0], actions, rewards[0], next_states[0], dones[0])

            score += env_info.rewards[0]

            states = next_states                               # roll over states to next time step
            if np.any(dones):                                  # exit loop if episode finished
                break
        

        #returns_in_episode = np.mean(scores)
        returns_in_episode = score
        scores_deque.append(returns_in_episode)
        score_history.append(returns_in_episode)
        if episode > scores_window:
            if mean(scores_deque) > last_running_mean:
                    print("")
                    print('Last {} was better, going to save it'.format(scores_window))
                    _, filename = get_constant_string()
                    torch.save(new_agent.actor_local.state_dict(), '{}/{}_actor.pth'.format(SAVE_PATH, filename))
                    torch.save(new_agent.critic_local.state_dict(), '{}/{}_critic.pth'.format(SAVE_PATH, filename))
                    last_running_mean = mean(scores_deque)

        print("\r", 'Total score (averaged over agents) {} episode: {} | \tAvarage in last {} is {}'.format(episode, returns_in_episode, scores_window, np.mean(scores_deque)), end="")


    render_save_graph(score_history, scores_window = SCORES_WINDOW, goal=30.)
    save_scores(score_history, path=SAVE_EXP_PATH)

    return score_history

# %%
new_agent = DDPG_Agent(state_size, action_size, random_seed = 1, actor_hidden = ACTOR_H, critic_hidden=CRITIC_H)
# Out:
# --- Agent Params ---
# Going to train on cuda:0
# Learning Rate:: Actor: 0.0001 | Critic: 0.0001
# Replay Buffer:: Buffer Size: 100000 | Sampled Batch size: 100
#
# Actor paramaters:: Input: 33 | Hidden Layers: [48, 48] | Output: 4
# Critic paramaters:: Input: 33 | Hidden Layers: [52, 48] | Output: 1
# Actor(
#   (fc_in): Linear(in_features=33, out_features=48, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=48, out_features=48, bias=True)
#   )
#   (fc_out): Linear(in_features=48, out_features=4, bias=True)
# )
# Critic(
#   (fc_in): Linear(in_features=33, out_features=48, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=52, out_features=48, bias=True)
#   )
#   (fc_out): Linear(in_features=48, out_features=1, bias=True)
# )

# %%
score_history = DDPG_train(new_agent, env, max_t = 1001, num_episodes = 750, scores_window=SCORES_WINDOW)
# Out:
# over agents) 172 episode: 9.71999978274107 | 	Avarage in last 100 is 5.0667998867481945
# Last 100 was better, going to save it
#  Total score (averaged over agents) 173 episode: 5.76999987103045 | 	Avarage in last 100 is 5.115799885652959
# Last 100 was better, going to save it
#  Total score (averaged over agents) 174 episode: 12.709999715909362 | 	Avarage in last 100 is 5.217799883373082
# Last 100 was better, going to save it
#  Total score (averaged over agents) 175 episode: 7.459999833256006 | 	Avarage in last 100 is 5.269599882215261
# Last 100 was better, going to save it
#  Total score (averaged over agents) 176 episode: 6.9999998435378075 | 	Avarage in last 100 is 5.308199881352484
# Last 100 was better, going to save it
#  Total score (averaged over agents) 177 episode: 2.9599999338388443 | 	Avarage in last 100 is 5.312799881249666
# Last 100 was better, going to save it
#  Total score (averaged over agents) 178 episode: 2.6399999409914017 | 	Avarage in last 100 is 5.318199881128967
# Last 100 was better, going to save it
#  Total score (averaged over agents) 179 episode: 6.159999862313271 | 	Avarage in last 100 is 5.364599880091846
# Last 100 was better, going to save it
#  Total score (averaged over agents) 180 episode: 7.239999838173389 | 	Avarage in last 100 is 5.390299879517406
# Last 100 was better, going to save it
#  Total score (averaged over agents) 181 episode: 8.379999812692404 | 	Avarage in last 100 is 5.45419987808913
# Last 100 was better, going to save it
#  Total score (averaged over agents) 182 episode: 6.819999847561121 | 	Avarage in last 100 is 5.468999877758324
# Last 100 was better, going to save it
#  Total score (averaged over agents) 183 episode: 10.769999759271741 | 	Avarage in last 100 is 5.509499876853079
# Last 100 was better, going to save it
#  Total score (averaged over agents) 184 episode: 8.16999981738627 | 	Avarage in last 100 is 5.575099875386805
# Last 100 was better, going to save it
#  Total score (averaged over agents) 185 episode: 7.229999838396907 | 	Avarage in last 100 is 5.617999874427914
# Last 100 was better, going to save it
#  Total score (averaged over agents) 186 episode: 5.039999887347221 | 	Avarage in last 100 is 5.641999873891473
# Last 100 was better, going to save it
#  Total score (averaged over agents) 187 episode: 10.429999766871333 | 	Avarage in last 100 is 5.721699872110039
# Last 100 was better, going to save it
#  Total score (averaged over agents) 188 episode: 8.609999807551503 | 	Avarage in last 100 is 5.733899871837348
# Last 100 was better, going to save it
#  Total score (averaged over agents) 189 episode: 10.949999755248427 | 	Avarage in last 100 is 5.77869987083599
# Last 100 was better, going to save it
#  Total score (averaged over agents) 190 episode: 8.759999804198742 | 	Avarage in last 100 is 5.837399869523942
# Last 100 was better, going to save it
#  Total score (averaged over agents) 191 episode: 9.979999776929617 | 	Avarage in last 100 is 5.927399867512285
# Last 100 was better, going to save it
#  Total score (averaged over agents) 192 episode: 10.329999769106507 | 	Avarage in last 100 is 6.015799865536391
# Last 100 was better, going to save it
#  Total score (averaged over agents) 193 episode: 12.609999718144536 | 	Avarage in last 100 is 6.136399862840772
# Last 100 was better, going to save it
#  Total score (averaged over agents) 194 episode: 6.959999844431877 | 	Avarage in last 100 is 6.183899861779064
# Last 100 was better, going to save it
#  Total score (averaged over agents) 195 episode: 11.49999974295497 | 	Avarage in last 100 is 6.275699859727174
# Last 100 was better, going to save it
#  Total score (averaged over agents) 196 episode: 13.539999697357416 | 	Avarage in last 100 is 6.400199856944382
# Last 100 was better, going to save it
#  Total score (averaged over agents) 197 episode: 5.9699998665601015 | 	Avarage in last 100 is 6.429399856291711
# Last 100 was better, going to save it
#  Total score (averaged over agents) 198 episode: 5.629999874159694 | 	Avarage in last 100 is 6.463299855533987
# Last 100 was better, going to save it
#  Total score (averaged over agents) 199 episode: 7.409999834373593 | 	Avarage in last 100 is 6.485299855042249
# Last 100 was better, going to save it
#  Total score (averaged over agents) 200 episode: 10.10999977402389 | 	Avarage in last 100 is 6.5316998540051285
# Last 100 was better, going to save it
#  Total score (averaged over agents) 201 episode: 11.709999738261104 | 	Avarage in last 100 is 6.588199852742255
# Last 100 was better, going to save it
#  Total score (averaged over agents) 202 episode: 6.599999852478504 | 	Avarage in last 100 is 6.643699851501733
# Last 100 was better, going to save it
#  Total score (averaged over agents) 203 episode: 10.839999757707119 | 	Avarage in last 100 is 6.734999849461019
# Last 100 was better, going to save it
#  Total score (averaged over agents) 204 episode: 11.719999738037586 | 	Avarage in last 100 is 6.832599847279489
# Last 100 was better, going to save it
#  Total score (averaged over agents) 205 episode: 9.819999780505896 | 	Avarage in last 100 is 6.892199845947325
# Last 100 was better, going to save it
#  Total score (averaged over agents) 206 episode: 9.389999790117145 | 	Avarage in last 100 is 6.9567998445034025
# Last 100 was better, going to save it
#  Total score (averaged over agents) 207 episode: 6.009999865666032 | 	Avarage in last 100 is 7.002199843488634
# Last 100 was better, going to save it
#  Total score (averaged over agents) 208 episode: 10.739999759942293 | 	Avarage in last 100 is 7.0673998420313
# Last 100 was better, going to save it
#  Total score (averaged over agents) 209 episode: 10.809999758377671 | 	Avarage in last 100 is 7.121699840817601
# Last 100 was better, going to save it
#  Total score (averaged over agents) 210 episode: 12.769999714568257 | 	Avarage in last 100 is 7.217999838665127
# Last 100 was better, going to save it
#  Total score (averaged over agents) 211 episode: 8.78999980352819 | 	Avarage in last 100 is 7.266899837572128
# Last 100 was better, going to save it
#  Total score (averaged over agents) 212 episode: 10.989999754354358 | 	Avarage in last 100 is 7.3634998354129495
# Last 100 was better, going to save it
#  Total score (averaged over agents) 213 episode: 11.259999748319387 | 	Avarage in last 100 is 7.43189983388409
# Last 100 was better, going to save it
#  Total score (averaged over agents) 214 episode: 7.949999822303653 | 	Avarage in last 100 is 7.448399833515286
# Last 100 was better, going to save it
#  Total score (averaged over agents) 215 episode: 13.509999698027968 | 	Avarage in last 100 is 7.5526998311839995
# Last 100 was better, going to save it
#  Total score (averaged over agents) 216 episode: 9.589999785646796 | 	Avarage in last 100 is 7.597099830191582
# Last 100 was better, going to save it
#  Total score (averaged over agents) 217 episode: 6.789999848231673 | 	Avarage in last 100 is 7.616999829746783
# Last 100 was better, going to save it
#  Total score (averaged over agents) 218 episode: 10.549999764189124 | 	Avarage in last 100 is 7.700699827875942
# Last 100 was better, going to save it
#  Total score (averaged over agents) 219 episode: 9.899999778717756 | 	Avarage in last 100 is 7.764299826454371
# Last 100 was better, going to save it
#  Total score (averaged over agents) 220 episode: 11.599999740719795 | 	Avarage in last 100 is 7.831299824956805
# Last 100 was better, going to save it
#  Total score (averaged over agents) 221 episode: 12.249999726191163 | 	Avarage in last 100 is 7.930499822739511
# Last 100 was better, going to save it
#  Total score (averaged over agents) 222 episode: 11.649999739602208 | 	Avarage in last 100 is 8.019499820750207
# Last 100 was better, going to save it
#  Total score (averaged over agents) 223 episode: 10.449999766424298 | 	Avarage in last 100 is 8.073299819547683
# Last 100 was better, going to save it
#  Total score (averaged over agents) 224 episode: 7.489999832585454 | 	Avarage in last 100 is 8.098699818979949
# Last 100 was better, going to save it
#  Total score (averaged over agents) 225 episode: 10.41999976709485 | 	Avarage in last 100 is 8.161199817582965
# Last 100 was better, going to save it
#  Total score (averaged over agents) 226 episode: 11.329999746754766 | 	Avarage in last 100 is 8.217199816331267
# Last 100 was better, going to save it
#  Total score (averaged over agents) 227 episode: 6.859999846667051 | 	Avarage in last 100 is 8.269599815160037
# Last 100 was better, going to save it
#  Total score (averaged over agents) 229 episode: 6.229999860748649 | 	Avarage in last 100 is 8.337699813637883
# Last 100 was better, going to save it
#  Total score (averaged over agents) 230 episode: 9.019999798387289 | 	Avarage in last 100 is 8.381299812663347
# Last 100 was better, going to save it
#  Total score (averaged over agents) 231 episode: 11.379999745637178 | 	Avarage in last 100 is 8.434199811480939
# Last 100 was better, going to save it
#  Total score (averaged over agents) 232 episode: 15.639999650418758 | 	Avarage in last 100 is 8.535599809214473
# Last 100 was better, going to save it
#  Total score (averaged over agents) 233 episode: 12.879999712109566 | 	Avarage in last 100 is 8.609699807558208
# Last 100 was better, going to save it
#  Total score (averaged over agents) 234 episode: 14.739999670535326 | 	Avarage in last 100 is 8.699699805546551
# Last 100 was better, going to save it
#  Total score (averaged over agents) 235 episode: 14.189999682828784 | 	Avarage in last 100 is 8.746299804504961
# Last 100 was better, going to save it
#  Total score (averaged over agents) 236 episode: 10.64999976195395 | 	Avarage in last 100 is 8.797399803362786
# Last 100 was better, going to save it
#  Total score (averaged over agents) 237 episode: 16.859999623149633 | 	Avarage in last 100 is 8.901499801035971
# Last 100 was better, going to save it
#  Total score (averaged over agents) 238 episode: 5.76999987103045 | 	Avarage in last 100 is 8.903299800995738
# Last 100 was better, going to save it
#  Total score (averaged over agents) 239 episode: 14.129999684169888 | 	Avarage in last 100 is 8.96529979960993
# Last 100 was better, going to save it
#  Total score (averaged over agents) 240 episode: 8.279999814927578 | 	Avarage in last 100 is 8.979899799283594
# Last 100 was better, going to save it
#  Total score (averaged over agents) 241 episode: 8.229999816045165 | 	Avarage in last 100 is 9.015599798485637
# Last 100 was better, going to save it
#  Total score (averaged over agents) 242 episode: 11.329999746754766 | 	Avarage in last 100 is 9.023699798304587
# Last 100 was better, going to save it
#  Total score (averaged over agents) 243 episode: 11.019999753683805 | 	Avarage in last 100 is 9.037299798000603
# Last 100 was better, going to save it
#  Total score (averaged over agents) 244 episode: 13.349999701604247 | 	Avarage in last 100 is 9.080799797028304
# Last 100 was better, going to save it
#  Total score (averaged over agents) 245 episode: 11.509999742731452 | 	Avarage in last 100 is 9.137599795758724
# Last 100 was better, going to save it
#  Total score (averaged over agents) 246 episode: 18.559999585151672 | 	Avarage in last 100 is 9.276699792649596
# Last 100 was better, going to save it
#  Total score (averaged over agents) 247 episode: 11.76999973692 | 	Avarage in last 100 is 9.3235997916013
# Last 100 was better, going to save it
#  Total score (averaged over agents) 248 episode: 10.25999977067113 | 	Avarage in last 100 is 9.34929979102686
# Last 100 was better, going to save it
#  Total score (averaged over agents) 249 episode: 14.24999968148768 | 	Avarage in last 100 is 9.386199790202081
# Last 100 was better, going to save it
#  Total score (averaged over agents) 250 episode: 11.469999743625522 | 	Avarage in last 100 is 9.429399789236486
# Last 100 was better, going to save it
#  Total score (averaged over agents) 252 episode: 3.7399999164044857 | 	Avarage in last 100 is 9.505799787528813
# Last 100 was better, going to save it
#  Total score (averaged over agents) 253 episode: 14.069999685510993 | 	Avarage in last 100 is 9.588299785684795
# Last 100 was better, going to save it
#  Total score (averaged over agents) 254 episode: 19.90999955497682 | 	Avarage in last 100 is 9.729599782526494
# Last 100 was better, going to save it
#  Total score (averaged over agents) 255 episode: 19.86999955587089 | 	Avarage in last 100 is 9.872299779336899
# Last 100 was better, going to save it
#  Total score (averaged over agents) 256 episode: 8.649999806657434 | 	Avarage in last 100 is 9.897699778769166
# Last 100 was better, going to save it
#  Total score (averaged over agents) 257 episode: 16.60999962873757 | 	Avarage in last 100 is 9.990399776697158
# Last 100 was better, going to save it
#  Total score (averaged over agents) 258 episode: 15.539999652653933 | 	Avarage in last 100 is 10.068099774960428
# Last 100 was better, going to save it
#  Total score (averaged over agents) 259 episode: 13.879999689757824 | 	Avarage in last 100 is 10.152099773082883
# Last 100 was better, going to save it
#  Total score (averaged over agents) 260 episode: 12.309999724850059 | 	Avarage in last 100 is 10.229799771346151
# Last 100 was better, going to save it
#  Total score (averaged over agents) 262 episode: 5.199999883770943 | 	Avarage in last 100 is 10.289799770005047
# Last 100 was better, going to save it
#  Total score (averaged over agents) 263 episode: 22.73999949172139 | 	Avarage in last 100 is 10.446999766491354
# Last 100 was better, going to save it
#  Total score (averaged over agents) 265 episode: 9.189999794587493 | 	Avarage in last 100 is 10.475499765854329
# Last 100 was better, going to save it
#  Total score (averaged over agents) 267 episode: 4.559999898076057 | 	Avarage in last 100 is 10.572999763675034
# Last 100 was better, going to save it
#  Total score (averaged over agents) 268 episode: 10.72999976016581 | 	Avarage in last 100 is 10.607899762894958
# Last 100 was better, going to save it
#  Total score (averaged over agents) 270 episode: 8.379999812692404 | 	Avarage in last 100 is 10.636599762253462
# Last 100 was better, going to save it
#  Total score (averaged over agents) 271 episode: 21.60999951697886 | 	Avarage in last 100 is 10.758099759537727
# Last 100 was better, going to save it
#  Total score (averaged over agents) 272 episode: 14.20999968238175 | 	Avarage in last 100 is 10.802999758534133
# Last 100 was better, going to save it
#  Total score (averaged over agents) 275 episode: 13.239999704062939 | 	Avarage in last 100 is 10.86839975707233
# Last 100 was better, going to save it
#  Total score (averaged over agents) 276 episode: 18.00999959744513 | 	Avarage in last 100 is 10.978499754611402
# Last 100 was better, going to save it
#  Total score (averaged over agents) 277 episode: 12.139999728649855 | 	Avarage in last 100 is 11.070299752559514
# Last 100 was better, going to save it
#  Total score (averaged over agents) 278 episode: 13.589999696239829 | 	Avarage in last 100 is 11.179799750111997
# Last 100 was better, going to save it
#  Total score (averaged over agents) 279 episode: 16.989999620243907 | 	Avarage in last 100 is 11.288099747691303
# Last 100 was better, going to save it
#  Total score (averaged over agents) 280 episode: 13.549999697133899 | 	Avarage in last 100 is 11.351199746280908
# Last 100 was better, going to save it
#  Total score (averaged over agents) 281 episode: 16.91999962180853 | 	Avarage in last 100 is 11.436599744372069
# Last 100 was better, going to save it
#  Total score (averaged over agents) 282 episode: 24.449999453499913 | 	Avarage in last 100 is 11.612899740431457
# Last 100 was better, going to save it
#  Total score (averaged over agents) 283 episode: 22.179999504238367 | 	Avarage in last 100 is 11.726999737881124
# Last 100 was better, going to save it
#  Total score (averaged over agents) 285 episode: 6.899999845772982 | 	Avarage in last 100 is 11.805699736122042
# Last 100 was better, going to save it
#  Total score (averaged over agents) 286 episode: 23.369999477639794 | 	Avarage in last 100 is 11.988999732024968
# Last 100 was better, going to save it
#  Total score (averaged over agents) 292 episode: 9.329999791458249 | 	Avarage in last 100 is 12.060199730433524
# Last 100 was better, going to save it
#  Total score (averaged over agents) 293 episode: 16.719999626278877 | 	Avarage in last 100 is 12.101299729514867
# Last 100 was better, going to save it
#  Total score (averaged over agents) 294 episode: 21.71999951452017 | 	Avarage in last 100 is 12.24889972621575
# Last 100 was better, going to save it
#  Total score (averaged over agents) 296 episode: 7.459999833256006 | 	Avarage in last 100 is 12.24389972632751
# Last 100 was better, going to save it
#  Total score (averaged over agents) 297 episode: 15.389999656006694 | 	Avarage in last 100 is 12.338099724221975
# Last 100 was better, going to save it
#  Total score (averaged over agents) 298 episode: 20.55999954044819 | 	Avarage in last 100 is 12.48739972088486
# Last 100 was better, going to save it
#  Total score (averaged over agents) 299 episode: 16.779999624937773 | 	Avarage in last 100 is 12.581099718790501
# Last 100 was better, going to save it
#  Total score (averaged over agents) 301 episode: 7.179999839514494 | 	Avarage in last 100 is 12.549199719503521
# Last 100 was better, going to save it
#  Total score (averaged over agents) 302 episode: 13.239999704062939 | 	Avarage in last 100 is 12.615599718019366
# Last 100 was better, going to save it
#  Total score (averaged over agents) 311 episode: 11.249999748542905 | 	Avarage in last 100 is 12.655399717129766
# Last 100 was better, going to save it
#  Total score (averaged over agents) 312 episode: 18.62999958358705 | 	Avarage in last 100 is 12.731799715422094
# Last 100 was better, going to save it
#  Total score (averaged over agents) 314 episode: 5.45999987795949 | 	Avarage in last 100 is 12.76279971472919
# Last 100 was better, going to save it
#  Total score (averaged over agents) 315 episode: 17.22999961487949 | 	Avarage in last 100 is 12.799999713897705
# Last 100 was better, going to save it
#  Total score (averaged over agents) 316 episode: 13.469999698922038 | 	Avarage in last 100 is 12.838799713030458
# Last 100 was better, going to save it
#  Total score (averaged over agents) 317 episode: 14.429999677464366 | 	Avarage in last 100 is 12.915199711322785
# Last 100 was better, going to save it
#  Total score (averaged over agents) 318 episode: 20.05999955162406 | 	Avarage in last 100 is 13.010299709197135
# Last 100 was better, going to save it
#  Total score (averaged over agents) 319 episode: 17.879999600350857 | 	Avarage in last 100 is 13.090099707413465
# Last 100 was better, going to save it
#  Total score (averaged over agents) 320 episode: 22.219999503344297 | 	Avarage in last 100 is 13.19629970503971
# Last 100 was better, going to save it
#  Total score (averaged over agents) 321 episode: 17.449999609962106 | 	Avarage in last 100 is 13.24829970387742
# Last 100 was better, going to save it
#  Total score (averaged over agents) 323 episode: 8.609999807551503 | 	Avarage in last 100 is 13.250299703832717
# Last 100 was better, going to save it
#  Total score (averaged over agents) 324 episode: 13.819999691098928 | 	Avarage in last 100 is 13.31359970241785
# Last 100 was better, going to save it
#  Total score (averaged over agents) 325 episode: 13.589999696239829 | 	Avarage in last 100 is 13.345299701709301
# Last 100 was better, going to save it
#  Total score (averaged over agents) 326 episode: 20.75999953597784 | 	Avarage in last 100 is 13.439599699601532
# Last 100 was better, going to save it
#  Total score (averaged over agents) 339 episode: 15.329999657347798 | 	Avarage in last 100 is 13.411699700225144
# Last 100 was better, going to save it
#  Total score (averaged over agents) 340 episode: 24.969999441877007 | 	Avarage in last 100 is 13.578599696494638
# Last 100 was better, going to save it
#  Total score (averaged over agents) 342 episode: 9.109999796375632 | 	Avarage in last 100 is 13.56639969676733
# Last 100 was better, going to save it
#  Total score (averaged over agents) 351 episode: 21.159999527037144 | 	Avarage in last 100 is 13.621599695533513
# Last 100 was better, going to save it
#  Total score (averaged over agents) 749 episode: 2.7899999376386404 | 	Avarage in last 100 is 5.733799871839583
# Scores saved!

# %% [markdown]
# # Display and Save results

# %%
render_save_graph(score_history, scores_window = SCORES_WINDOW, goal=30.)

# %%
save_scores(score_history, path=SAVE_EXP_PATH)

# %%
new_score_history = DDPG_train(new_agent, env, max_t = 1001, num_episodes = 500, scores_window=SCORES_WINDOW, existing_score=score_history)

# %% [markdown]
# # Continue last saved run
# The next to cells
# - Import the scores of the last run
# - If we saved weights of the Neural Net load those
# - Continue training from last place

# %%
new_agent = load_previous(new_agent)

# %%
network_name='Scores_2021-04-17_2257_A_128 128 - C_128 128'
read_score_history = read_scores(network_name=network_name, path=SAVE_EXP_PATH)

render_save_graph(read_score_history, scores_window = SCORES_WINDOW, goal=30.) # Check how it looks

# %%
new_score_history = DDPG_train(new_agent, env, max_t = 1001, num_episodes = 150, existing_score=read_score_history, scores_window=SCORES_WINDOW)

# %%
render_graph(new_score_history, scores_window = SCORES_WINDOW)

# %%
save_scores(new_score_history, path=SAVE_EXP_PATH)

# %% [markdown]
# # See how the agent performs

# %%
new_agent = DDPG_Agent(state_size, action_size, random_seed = 3, actor_hidden = ACTOR_H, critic_hidden=CRITIC_H)
new_agent = load_previous(new_agent)

# %%
def DDPG_eval(agent, env, max_t=100):
    env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
    states = env_info.vector_observations                  # get the current state (for each agent)
    scores = np.zeros(num_agents)                          # initialize the score (for each agent)
    episode_length = 0                                     # measure number of steps allowed before done flag
    for i in range(max_t):
        # actions = np.random.randn(num_agents, action_size) # select an action (for each agent); randomly!
        actions =  np.random.randn(num_agents, action_size) if agent is None else agent.act(states[0]) # select an action (for each agent)
        actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
        env_info = env.step(actions)[brain_name]           # send all actions to the environment
        next_states = env_info.vector_observations         # get next state (for each agent)
        rewards = env_info.rewards                         # get reward (for each agent)
        dones = env_info.local_done                        # see if episode finished
        scores += env_info.rewards                         # update the score (for each agent)
        states = next_states                               # roll over states to next time step
        episode_length +=1
        if np.any(dones):                                  # exit loop if episode finished
            break
    print('Episode length is {}'.format(episode_length))
    print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %%
DDPG_eval(new_agent, env, max_t = 100000000000)

# %%
env.close()
