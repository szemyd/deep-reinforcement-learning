# %% [markdown]
# # DDPG Agent

# %% [markdown]
# ## Import necessary modules

# %%
# --- General NN and math libraries --- #
import numpy as np
import torch

# --- For Measuring performance --- #
from collections import deque
from statistics import mean, stdev
import matplotlib.pyplot as plt

# --- For Loading the environment --- #
from e_env import environment_loader

# --- For plotting and saving --- #
from constants import *             # Capital lettered variables are constants from the constants.py file
import time
import csv
from monitor import render_save_graph, save_scores, read_scores
print_constants()

# --- Loading and Nameing utilities --- #
from helper import load_previous, get_constant_string
# Out:
# --- General Training parameters ---
# DEVICE:  cuda:0
# SCORES_WINDOW:  100
# SAVE_PATH:  Trained_Agents/
# SAVE_EXP_PATH:  Experiments/
#
# --- Replay Buffer parameters ---
# BUFFER_SIZE:  100000
# UPDATE_EVERY:  4
# BATCH_SIZE:  100
#
# --- Learning parameters ---
# GAMMA:  0.99
# LR_ACTOR:  0.0001
# LR_CRITIC:  0.0001
# CRITERION:  <function mse_loss at 0x00000243E87F4EA0>
# WEIGHT_DECAY:  0
# TAU:  0.001
#
# --- OUNoise ---
# MU:  0.0
# THETA:  0.15
# SIGMA:  0.05

# %%
# --- For Loading the agent --- #
# We don't need to reimport the agent everytime we change one of it's values
# %load_ext autoreload
# %autoreload 2
from a_agent import DDPG_Agent

# %% [markdown]
# ## Load Environment
# Environment is loaded with a helper function in ENV.py
# The helper function returns the envrionment object, the state size and action size, the brain's name and how many agents there are in the environment

# %%
env, state_size, action_size, brain_name, num_agents = environment_loader("Reacher_Single/Reacher.exe", no_graphics = True)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# # Train Agent

# %%
score_history = []

# %%
def DDPG_train(agent, env, max_t=100, num_episodes = 1, scores_window=SCORES_WINDOW, existing_score=[]):
    [score_history.append(i) for i in existing_score]
    print("Continuing training -> initial Score History length: ", len(score_history))
    
    scores_deque = deque(score_history[-scores_window:], maxlen=scores_window)
    last_running_mean = float('-inf')

    for episode in range(num_episodes):
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        agent.reset()                                          # reset the noise in the agent
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores = np.zeros(num_agents)                          # initialize the score (for each agent)
        score = 0

        for i in range(max_t):
            actions = agent.act(states[0])                     # select an action (for each agent)
            env_info = env.step(actions)[brain_name]           # send all actions to the environment
            
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished

            agent.step(states[0], actions, rewards[0], next_states[0], dones[0])

            score += env_info.rewards[0]

            states = next_states                               # roll over states to next time step
            if np.any(dones):                                  # exit loop if episode finished
                break
        

        #returns_in_episode = np.mean(scores)
        returns_in_episode = score
        scores_deque.append(returns_in_episode)
        score_history.append(returns_in_episode)
        if episode > scores_window:
            if mean(scores_deque) > last_running_mean:
                    print("")
                    print('Last {} was better, going to save it'.format(scores_window))
                    _, filename = get_constant_string()
                    torch.save(new_agent.actor_local.state_dict(), '{}/{}_actor.pth'.format(SAVE_PATH, filename))
                    torch.save(new_agent.critic_local.state_dict(), '{}/{}_critic.pth'.format(SAVE_PATH, filename))
                    last_running_mean = mean(scores_deque)

        print("\r", 'Total score (averaged over agents) {} episode: {} | \tAvarage in last {} is {}'.format(episode, returns_in_episode, scores_window, np.mean(scores_deque)), end="")


    render_save_graph(score_history, scores_window = SCORES_WINDOW, goal=30.)
    save_scores(score_history, path=SAVE_EXP_PATH)

    return score_history

# %%
new_agent = DDPG_Agent(state_size, action_size, random_seed = 1, actor_hidden = ACTOR_H, critic_hidden=CRITIC_H)
# Out:
# --- Agent Params ---
# Going to train on cuda:0
# Learning Rate:: Actor: 0.0001 | Critic: 0.0001
# Replay Buffer:: Buffer Size: 100000 | Sampled Batch size: 100
#
# Actor paramaters:: Input: 33 | Hidden Layers: [160, 160] | Output: 4
# Critic paramaters:: Input: 33 | Hidden Layers: [164, 160] | Output: 1
# Actor(
#   (fc_in): Linear(in_features=33, out_features=160, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=160, out_features=160, bias=True)
#   )
#   (fc_out): Linear(in_features=160, out_features=4, bias=True)
# )
# Critic(
#   (fc_in): Linear(in_features=33, out_features=160, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=164, out_features=160, bias=True)
#   )
#   (fc_out): Linear(in_features=160, out_features=1, bias=True)
# )

# %%
score_history = DDPG_train(new_agent, env, max_t = 1001, num_episodes = 750, scores_window=SCORES_WINDOW)
# Out:
# 9982758984
# Last 100 was better, going to save it
#  Total score (averaged over agents) 136 episode: 17.259999614208937 | 	Avarage in last 100 is 7.867399824149906
# Last 100 was better, going to save it
#  Total score (averaged over agents) 137 episode: 19.109999572858214 | 	Avarage in last 100 is 8.042699820231647
# Last 100 was better, going to save it
#  Total score (averaged over agents) 138 episode: 18.12999959476292 | 	Avarage in last 100 is 8.208699816521257
# Last 100 was better, going to save it
#  Total score (averaged over agents) 139 episode: 22.92999948747456 | 	Avarage in last 100 is 8.42899981159717
# Last 100 was better, going to save it
#  Total score (averaged over agents) 140 episode: 23.299999479204416 | 	Avarage in last 100 is 8.654399806559086
# Last 100 was better, going to save it
#  Total score (averaged over agents) 141 episode: 18.179999593645334 | 	Avarage in last 100 is 8.818499802891164
# Last 100 was better, going to save it
#  Total score (averaged over agents) 142 episode: 38.33999914303422 | 	Avarage in last 100 is 9.17999979481101
# Last 100 was better, going to save it
#  Total score (averaged over agents) 143 episode: 17.319999612867832 | 	Avarage in last 100 is 9.337699791286141
# Last 100 was better, going to save it
#  Total score (averaged over agents) 144 episode: 26.229999413713813 | 	Avarage in last 100 is 9.582099785823376
# Last 100 was better, going to save it
#  Total score (averaged over agents) 145 episode: 21.849999511614442 | 	Avarage in last 100 is 9.77199978157878
# Last 100 was better, going to save it
#  Total score (averaged over agents) 146 episode: 19.269999569281936 | 	Avarage in last 100 is 9.918899778295309
# Last 100 was better, going to save it
#  Total score (averaged over agents) 147 episode: 18.369999589398503 | 	Avarage in last 100 is 10.08969977447763
# Last 100 was better, going to save it
#  Total score (averaged over agents) 148 episode: 26.59999940544367 | 	Avarage in last 100 is 10.325399769209325
# Last 100 was better, going to save it
#  Total score (averaged over agents) 149 episode: 31.069999305531383 | 	Avarage in last 100 is 10.605399762950837
# Last 100 was better, going to save it
#  Total score (averaged over agents) 150 episode: 27.709999380633235 | 	Avarage in last 100 is 10.849899757485836
# Last 100 was better, going to save it
#  Total score (averaged over agents) 151 episode: 29.719999335706234 | 	Avarage in last 100 is 11.112999751605093
# Last 100 was better, going to save it
#  Total score (averaged over agents) 152 episode: 25.739999424666166 | 	Avarage in last 100 is 11.340499746520072
# Last 100 was better, going to save it
#  Total score (averaged over agents) 153 episode: 27.60999938286841 | 	Avarage in last 100 is 11.58639974102378
# Last 100 was better, going to save it
#  Total score (averaged over agents) 154 episode: 30.309999322518706 | 	Avarage in last 100 is 11.842299735303968
# Last 100 was better, going to save it
#  Total score (averaged over agents) 155 episode: 20.48999954201281 | 	Avarage in last 100 is 11.995099731888622
# Last 100 was better, going to save it
#  Total score (averaged over agents) 156 episode: 24.77999944612384 | 	Avarage in last 100 is 12.20579972717911
# Last 100 was better, going to save it
#  Total score (averaged over agents) 157 episode: 26.669999403879046 | 	Avarage in last 100 is 12.440299721937627
# Last 100 was better, going to save it
#  Total score (averaged over agents) 158 episode: 21.40999952144921 | 	Avarage in last 100 is 12.637499717529863
# Last 100 was better, going to save it
#  Total score (averaged over agents) 159 episode: 19.78999955765903 | 	Avarage in last 100 is 12.806399713754654
# Last 100 was better, going to save it
#  Total score (averaged over agents) 160 episode: 27.76999937929213 | 	Avarage in last 100 is 13.040299708526582
# Last 100 was better, going to save it
#  Total score (averaged over agents) 161 episode: 28.07999937236309 | 	Avarage in last 100 is 13.27689970323816
# Last 100 was better, going to save it
#  Total score (averaged over agents) 162 episode: 27.699999380856752 | 	Avarage in last 100 is 13.505599698126316
# Last 100 was better, going to save it
#  Total score (averaged over agents) 163 episode: 24.299999456852674 | 	Avarage in last 100 is 13.727299693170934
# Last 100 was better, going to save it
#  Total score (averaged over agents) 164 episode: 32.26999927870929 | 	Avarage in last 100 is 14.003599686995148
# Last 100 was better, going to save it
#  Total score (averaged over agents) 165 episode: 32.629999270662665 | 	Avarage in last 100 is 14.285099680703134
# Last 100 was better, going to save it
#  Total score (averaged over agents) 166 episode: 39.559999115765095 | 	Avarage in last 100 is 14.645099672656507
# Last 100 was better, going to save it
#  Total score (averaged over agents) 167 episode: 33.54999925009906 | 	Avarage in last 100 is 14.941199666038155
# Last 100 was better, going to save it
#  Total score (averaged over agents) 168 episode: 35.459999207407236 | 	Avarage in last 100 is 15.213499659951776
# Last 100 was better, going to save it
#  Total score (averaged over agents) 169 episode: 30.66999931447208 | 	Avarage in last 100 is 15.47029965421185
# Last 100 was better, going to save it
#  Total score (averaged over agents) 170 episode: 30.759999312460423 | 	Avarage in last 100 is 15.725899648498745
# Last 100 was better, going to save it
#  Total score (averaged over agents) 171 episode: 32.94999926351011 | 	Avarage in last 100 is 15.996399642452598
# Last 100 was better, going to save it
#  Total score (averaged over agents) 172 episode: 28.609999360516667 | 	Avarage in last 100 is 16.22209963740781
# Last 100 was better, going to save it
#  Total score (averaged over agents) 173 episode: 30.24999932385981 | 	Avarage in last 100 is 16.476299631725997
# Last 100 was better, going to save it
#  Total score (averaged over agents) 174 episode: 31.32999929971993 | 	Avarage in last 100 is 16.762399625331163
# Last 100 was better, going to save it
#  Total score (averaged over agents) 175 episode: 24.429999453946948 | 	Avarage in last 100 is 16.96829962072894
# Last 100 was better, going to save it
#  Total score (averaged over agents) 176 episode: 24.679999448359013 | 	Avarage in last 100 is 17.175899616088717
# Last 100 was better, going to save it
#  Total score (averaged over agents) 177 episode: 25.579999428242445 | 	Avarage in last 100 is 17.375399611629547
# Last 100 was better, going to save it
#  Total score (averaged over agents) 178 episode: 23.989999463781714 | 	Avarage in last 100 is 17.57819960709661
# Last 100 was better, going to save it
#  Total score (averaged over agents) 179 episode: 32.33999927714467 | 	Avarage in last 100 is 17.85559960089624
# Last 100 was better, going to save it
#  Total score (averaged over agents) 180 episode: 31.859999287873507 | 	Avarage in last 100 is 18.143099594470115
# Last 100 was better, going to save it
#  Total score (averaged over agents) 181 episode: 33.909999242052436 | 	Avarage in last 100 is 18.39809958877042
# Last 100 was better, going to save it
#  Total score (averaged over agents) 182 episode: 24.97999944165349 | 	Avarage in last 100 is 18.590899584461003
# Last 100 was better, going to save it
#  Total score (averaged over agents) 183 episode: 31.089999305084348 | 	Avarage in last 100 is 18.83829957893118
# Last 100 was better, going to save it
#  Total score (averaged over agents) 184 episode: 32.01999928429723 | 	Avarage in last 100 is 19.09849957311526
# Last 100 was better, going to save it
#  Total score (averaged over agents) 185 episode: 31.749999290332198 | 	Avarage in last 100 is 19.385999566689133
# Last 100 was better, going to save it
#  Total score (averaged over agents) 186 episode: 28.679999358952045 | 	Avarage in last 100 is 19.615999561548232
# Last 100 was better, going to save it
#  Total score (averaged over agents) 187 episode: 31.47999929636717 | 	Avarage in last 100 is 19.862799556031824
# Last 100 was better, going to save it
#  Total score (averaged over agents) 188 episode: 34.51999922841787 | 	Avarage in last 100 is 20.107199550569057
# Last 100 was better, going to save it
#  Total score (averaged over agents) 189 episode: 32.21999927982688 | 	Avarage in last 100 is 20.33979954537004
# Last 100 was better, going to save it
#  Total score (averaged over agents) 190 episode: 35.78999920003116 | 	Avarage in last 100 is 20.63859953869134
# Last 100 was better, going to save it
#  Total score (averaged over agents) 191 episode: 20.67999953776598 | 	Avarage in last 100 is 20.794099535215647
# Last 100 was better, going to save it
#  Total score (averaged over agents) 192 episode: 35.31999921053648 | 	Avarage in last 100 is 21.030999529920518
# Last 100 was better, going to save it
#  Total score (averaged over agents) 193 episode: 36.83999917656183 | 	Avarage in last 100 is 21.341499522980303
# Last 100 was better, going to save it
#  Total score (averaged over agents) 194 episode: 34.529999228194356 | 	Avarage in last 100 is 21.65579951595515
# Last 100 was better, going to save it
#  Total score (averaged over agents) 195 episode: 32.63999927043915 | 	Avarage in last 100 is 21.9046995103918
# Last 100 was better, going to save it
#  Total score (averaged over agents) 196 episode: 31.959999285638332 | 	Avarage in last 100 is 22.18609950410202
# Last 100 was better, going to save it
#  Total score (averaged over agents) 197 episode: 27.009999396279454 | 	Avarage in last 100 is 22.375799499861895
# Last 100 was better, going to save it
#  Total score (averaged over agents) 198 episode: 28.529999362304807 | 	Avarage in last 100 is 22.60239949479699
# Last 100 was better, going to save it
#  Total score (averaged over agents) 199 episode: 24.189999459311366 | 	Avarage in last 100 is 22.79949949039146
# Last 100 was better, going to save it
#  Total score (averaged over agents) 200 episode: 32.36999927647412 | 	Avarage in last 100 is 23.022899485398085
# Last 100 was better, going to save it
#  Total score (averaged over agents) 201 episode: 37.32999916560948 | 	Avarage in last 100 is 23.26629947995767
# Last 100 was better, going to save it
#  Total score (averaged over agents) 202 episode: 30.989999307319522 | 	Avarage in last 100 is 23.493199474886058
# Last 100 was better, going to save it
#  Total score (averaged over agents) 203 episode: 28.679999358952045 | 	Avarage in last 100 is 23.660499471146615
# Last 100 was better, going to save it
#  Total score (averaged over agents) 204 episode: 33.289999255910516 | 	Avarage in last 100 is 23.916099465433508
# Last 100 was better, going to save it
#  Total score (averaged over agents) 205 episode: 33.709999246522784 | 	Avarage in last 100 is 24.155599460080268
# Last 100 was better, going to save it
#  Total score (averaged over agents) 206 episode: 32.239999279379845 | 	Avarage in last 100 is 24.322799456343056
# Last 100 was better, going to save it
#  Total score (averaged over agents) 207 episode: 29.559999339282513 | 	Avarage in last 100 is 24.55499945115298
# Last 100 was better, going to save it
#  Total score (averaged over agents) 208 episode: 27.719999380409718 | 	Avarage in last 100 is 24.76199944652617
# Last 100 was better, going to save it
#  Total score (averaged over agents) 209 episode: 35.62999920360744 | 	Avarage in last 100 is 25.042699440252036
# Last 100 was better, going to save it
#  Total score (averaged over agents) 210 episode: 33.89999924227595 | 	Avarage in last 100 is 25.242199435792863
# Last 100 was better, going to save it
#  Total score (averaged over agents) 211 episode: 29.209999347105622 | 	Avarage in last 100 is 25.405699432138352
# Last 100 was better, going to save it
#  Total score (averaged over agents) 212 episode: 35.839999198913574 | 	Avarage in last 100 is 25.646299426760525
# Last 100 was better, going to save it
#  Total score (averaged over agents) 213 episode: 30.54999931715429 | 	Avarage in last 100 is 25.8757994216308
# Last 100 was better, going to save it
#  Total score (averaged over agents) 214 episode: 25.12999943830073 | 	Avarage in last 100 is 26.003699418772012
# Last 100 was better, going to save it
#  Total score (averaged over agents) 215 episode: 35.9399991966784 | 	Avarage in last 100 is 26.30119941212237
# Last 100 was better, going to save it
#  Total score (averaged over agents) 216 episode: 37.56999916024506 | 	Avarage in last 100 is 26.56689940618351
# Last 100 was better, going to save it
#  Total score (averaged over agents) 217 episode: 37.79999915510416 | 	Avarage in last 100 is 26.831599400267006
# Last 100 was better, going to save it
#  Total score (averaged over agents) 218 episode: 39.139999125152826 | 	Avarage in last 100 is 27.06649939501658
# Last 100 was better, going to save it
#  Total score (averaged over agents) 219 episode: 37.01999917253852 | 	Avarage in last 100 is 27.322499389294535
# Last 100 was better, going to save it
#  Total score (averaged over agents) 220 episode: 38.22999914549291 | 	Avarage in last 100 is 27.51919938489795
# Last 100 was better, going to save it
#  Total score (averaged over agents) 221 episode: 30.769999312236905 | 	Avarage in last 100 is 27.686199381165206
# Last 100 was better, going to save it
#  Total score (averaged over agents) 222 episode: 31.17999930307269 | 	Avarage in last 100 is 27.872599376998842
# Last 100 was better, going to save it
#  Total score (averaged over agents) 223 episode: 38.129999147728086 | 	Avarage in last 100 is 28.110799371674656
# Last 100 was better, going to save it
#  Total score (averaged over agents) 224 episode: 30.989999307319522 | 	Avarage in last 100 is 28.249999368563294
# Last 100 was better, going to save it
#  Total score (averaged over agents) 225 episode: 28.1899993699044 | 	Avarage in last 100 is 28.35869936613366
# Last 100 was better, going to save it
#  Total score (averaged over agents) 226 episode: 36.31999918818474 | 	Avarage in last 100 is 28.48029936341569
# Last 100 was better, going to save it
#  Total score (averaged over agents) 227 episode: 15.969999643042684 | 	Avarage in last 100 is 28.541599362045527
# Last 100 was better, going to save it
#  Total score (averaged over agents) 228 episode: 33.58999924920499 | 	Avarage in last 100 is 28.650399359613658
# Last 100 was better, going to save it
#  Total score (averaged over agents) 229 episode: 21.399999521672726 | 	Avarage in last 100 is 28.687299358788877
# Last 100 was better, going to save it
#  Total score (averaged over agents) 230 episode: 34.559999227523804 | 	Avarage in last 100 is 28.895899354126303
# Last 100 was better, going to save it
#  Total score (averaged over agents) 231 episode: 37.14999916963279 | 	Avarage in last 100 is 29.059399350471793
# Last 100 was better, going to save it
#  Total score (averaged over agents) 232 episode: 38.25999914482236 | 	Avarage in last 100 is 29.28439934544265
# Last 100 was better, going to save it
#  Total score (averaged over agents) 233 episode: 32.82999926619232 | 	Avarage in last 100 is 29.411299342606217
# Last 100 was better, going to save it
#  Total score (averaged over agents) 234 episode: 37.72999915666878 | 	Avarage in last 100 is 29.634899337608367
# Last 100 was better, going to save it
#  Total score (averaged over agents) 235 episode: 37.36999916471541 | 	Avarage in last 100 is 29.75389933494851
# Last 100 was better, going to save it
#  Total score (averaged over agents) 236 episode: 33.84999924339354 | 	Avarage in last 100 is 29.919799331240355
# Last 100 was better, going to save it
#  Total score (averaged over agents) 237 episode: 31.94999928586185 | 	Avarage in last 100 is 30.04819932837039
# Last 100 was better, going to save it
#  Total score (averaged over agents) 238 episode: 25.079999439418316 | 	Avarage in last 100 is 30.117699326816947
# Last 100 was better, going to save it
#  Total score (averaged over agents) 239 episode: 37.74999915622175 | 	Avarage in last 100 is 30.265899323504417
# Last 100 was better, going to save it
#  Total score (averaged over agents) 240 episode: 27.439999386668205 | 	Avarage in last 100 is 30.307299322579055
# Last 100 was better, going to save it
#  Total score (averaged over agents) 242 episode: 28.489999363198876 | 	Avarage in last 100 is 30.342099321801214
# Last 100 was better, going to save it
#  Total score (averaged over agents) 243 episode: 31.999999284744263 | 	Avarage in last 100 is 30.48889931851998
# Last 100 was better, going to save it
#  Total score (averaged over agents) 244 episode: 35.38999920897186 | 	Avarage in last 100 is 30.58049931647256
# Last 100 was better, going to save it
#  Total score (averaged over agents) 245 episode: 32.95999926328659 | 	Avarage in last 100 is 30.691599313989283
# Last 100 was better, going to save it
#  Total score (averaged over agents) 246 episode: 34.54999922774732 | 	Avarage in last 100 is 30.844399310573934
# Last 100 was better, going to save it
#  Total score (averaged over agents) 247 episode: 37.87999915331602 | 	Avarage in last 100 is 31.03949930621311
# Last 100 was better, going to save it
#  Total score (averaged over agents) 250 episode: 31.609999293461442 | 	Avarage in last 100 is 31.03779930625111
# Last 100 was better, going to save it
#  Total score (averaged over agents) 252 episode: 20.579999540001154 | 	Avarage in last 100 is 31.041399306170643
# Last 100 was better, going to save it
#  Total score (averaged over agents) 253 episode: 35.44999920763075 | 	Avarage in last 100 is 31.119799304418265
# Last 100 was better, going to save it
#  Total score (averaged over agents) 254 episode: 33.299999255687 | 	Avarage in last 100 is 31.149699303749948
# Last 100 was better, going to save it
#  Total score (averaged over agents) 255 episode: 31.439999297261238 | 	Avarage in last 100 is 31.259199301302434
# Last 100 was better, going to save it
#  Total score (averaged over agents) 256 episode: 26.729999402537942 | 	Avarage in last 100 is 31.278699300866574
# Last 100 was better, going to save it
#  Total score (averaged over agents) 257 episode: 31.039999306201935 | 	Avarage in last 100 is 31.322399299889803
# Last 100 was better, going to save it
#  Total score (averaged over agents) 258 episode: 34.529999228194356 | 	Avarage in last 100 is 31.453599296957254
# Last 100 was better, going to save it
#  Total score (averaged over agents) 259 episode: 33.02999926172197 | 	Avarage in last 100 is 31.585999293997883
# Last 100 was better, going to save it
#  Total score (averaged over agents) 260 episode: 32.979999262839556 | 	Avarage in last 100 is 31.63809929283336
# Last 100 was better, going to save it
#  Total score (averaged over agents) 262 episode: 17.479999609291553 | 	Avarage in last 100 is 31.59569929378107
# Last 100 was better, going to save it
#  Total score (averaged over agents) 263 episode: 38.24999914504588 | 	Avarage in last 100 is 31.735199290663004
# Last 100 was better, going to save it
#  Total score (averaged over agents) 277 episode: 37.79999915510416 | 	Avarage in last 100 is 31.63839929282665
# Last 100 was better, going to save it
#  Total score (averaged over agents) 278 episode: 35.179999213665724 | 	Avarage in last 100 is 31.750299290325493
# Last 100 was better, going to save it
#  Total score (averaged over agents) 279 episode: 36.069999193772674 | 	Avarage in last 100 is 31.787599289491773
# Last 100 was better, going to save it
#  Total score (averaged over agents) 280 episode: 38.749999133870006 | 	Avarage in last 100 is 31.85649928795174
# Last 100 was better, going to save it
#  Total score (averaged over agents) 281 episode: 36.70999917946756 | 	Avarage in last 100 is 31.884499287325887
# Last 100 was better, going to save it
#  Total score (averaged over agents) 282 episode: 32.41999927535653 | 	Avarage in last 100 is 31.95889928566292
# Last 100 was better, going to save it
#  Total score (averaged over agents) 283 episode: 34.909999219700694 | 	Avarage in last 100 is 31.99709928480908
# Last 100 was better, going to save it
#  Total score (averaged over agents) 285 episode: 23.369999477639794 | 	Avarage in last 100 is 31.971799285374583
# Last 100 was better, going to save it
#  Total score (averaged over agents) 286 episode: 38.09999914839864 | 	Avarage in last 100 is 32.06599928326905
# Last 100 was better, going to save it
#  Total score (averaged over agents) 749 episode: 32.68999926932156 | 	Avarage in last 100 is 30.144499326217918No file name specified to save to
# Scores saved!

# %% [markdown]
# # Display and Save results

# %%
render_save_graph(score_history[:350], scores_window = SCORES_WINDOW, goal=30.)
# Out:
# No file name specified to save to

# %%
save_scores(score_history, path=SAVE_EXP_PATH)
# Out:
# Scores saved!

# %%
new_score_history = DDPG_train(new_agent, env, max_t = 1001, num_episodes = 500, scores_window=SCORES_WINDOW, existing_score=score_history)

# %% [markdown]
# # Continue last saved run
# The next to cells
# - Import the scores of the last run
# - If we saved weights of the Neural Net load those
# - Continue training from last place

# %%
new_agent = load_previous(new_agent)

# %%
network_name='2021-04-17_2257_A_128 128 - C_128 128'
read_score_history = read_scores(network_name="Scores_" + network_name, path=SAVE_EXP_PATH)

render_save_graph(read_score_history, save_name='Figure_' + network_name, scores_window = SCORES_WINDOW, goal=30.) # Check how it looks

# %%
new_score_history = DDPG_train(new_agent, env, max_t = 1001, num_episodes = 150, existing_score=read_score_history, scores_window=SCORES_WINDOW)

# %%
render_graph(new_score_history, scores_window = SCORES_WINDOW)

# %%
save_scores(new_score_history, path=SAVE_EXP_PATH)

# %% [markdown]
# # See how the agent performs

# %%
new_agent = DDPG_Agent(state_size, action_size, random_seed = 3, actor_hidden = ACTOR_H, critic_hidden=CRITIC_H)
new_agent = load_previous(new_agent)

# %%
def DDPG_eval(agent, env, max_t=100):
    env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
    states = env_info.vector_observations                  # get the current state (for each agent)
    scores = np.zeros(num_agents)                          # initialize the score (for each agent)
    episode_length = 0                                     # measure number of steps allowed before done flag
    for i in range(max_t):
        # actions = np.random.randn(num_agents, action_size) # select an action (for each agent); randomly!
        actions =  np.random.randn(num_agents, action_size) if agent is None else agent.act(states[0]) # select an action (for each agent)
        actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
        env_info = env.step(actions)[brain_name]           # send all actions to the environment
        next_states = env_info.vector_observations         # get next state (for each agent)
        rewards = env_info.rewards                         # get reward (for each agent)
        dones = env_info.local_done                        # see if episode finished
        scores += env_info.rewards                         # update the score (for each agent)
        states = next_states                               # roll over states to next time step
        episode_length +=1
        if np.any(dones):                                  # exit loop if episode finished
            break
    print('Episode length is {}'.format(episode_length))
    print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %%
DDPG_eval(new_agent, env, max_t = 1000)

# %%
env.close()
